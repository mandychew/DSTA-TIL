# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random as rng
# import itertools

import librosa as lb
from librosa.display import specshow
import IPython.display as ipd


import sklearn as sk
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# %matplotlib inline

# %%
#  --  Defining Variables  --  #

max_ms = 4000

batchs = 32
epochs = 100

ind_to_label = {
    0 : 'angry',
    1 : 'fear',
    2 : 'happy',
    3 : 'neutral',
    4 : 'sad'
}

label_to_ind = { 
    lab: ind for ind, lab in ind_to_label.items()
    }

# %%
'''
Data insights

'''

class aud_stats:
    @staticmethod
    def average_sr():
        pass

# %%
'''

PREPROCESSING UTILS


'''


class aud_util:
    
    @staticmethod
    def loadaud(audio_file_path, sr=None, mono=False):                                 # load audio file, *mono argument (bool) can auto convert to mono, while default sr is converted to 22050*
        return lb.load(audio_file_path, sr=sr, mono=mono)                              # returns (data, sr)       

    @staticmethod
    def tf_loadaud(audio_file_path, sr=-1, mono=False):                                # only works with 16-bit audio
        file = tf.io.read_file(audio_file_path)
        
        if mono:
            dc = 1
        elif not mono:
            dc = -1
        
        return tf.audio.decode_wav(file, desired_channels=dc, desired_samples=sr)
    
    @staticmethod
    def mono_channel_withsr(audio_data_with_sr):
        return lb.to_mono(audio_data_with_sr[0]), audio_data_with_sr[1]

    @staticmethod
    def resample_withsr(data, in_sr, new_sr=22050):
        if in_sr == new_sr:
            return data
        else:
            return lb.resample(data, orig_sr=sr, new_sr=new_sr)
    
    @staticmethod
    def pad_trunc(aud, sr, target_ms):                                                 # padding places shorter audio randomly within the time frame of the padded length
        maxlen = (target_ms//1000)*sr
        
        if len(aud) == maxlen:
            return aud, sr

        elif len(aud) > maxlen:
            return aud[:maxlen], sr

        elif len(aud) < maxlen:
            
            # random padding positions
            pad_begin_len = rng.randint(0, maxlen - len(aud))
            pad_end_len = maxlen - len(aud) - pad_begin_len

            #actaual padding
            pad_begin = np.zeros((pad_begin_len))
            pad_end = np.zeros((pad_end_len))

            return np.concatenate((pad_begin, aud, pad_end), 0), sr



class aud_img:
    @staticmethod
    def melspec(data, sr):
        spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
        spec = lb.amplitude_to_db(spec, ref=np.min)
        return spec

    @staticmethod
    def mfcc(data, sr):
        mfcc_ = lb.feature.mfcc(data, sr)
        #mfcc_ = sk.preprocessing.scale(mfcc_, axis=1)
        return mfcc_

    @staticmethod
    def display_audio_img(spec, sr , mfcc=False):
        fig, ax = plt.subplots()
        
        if mfcc:
            specshow(spec, sr=sr, x_axis='time')
        else:
            img = specshow(spec, x_axis='time', y_axis='mel', sr=sr, fmax=8000, ax=ax)
            fig.colorbar(img, ax=ax, format='%+2.0f dB')



class ds_create:
    
    @staticmethod    
    def label_from_bpath(bpath):                                                       # probably will not be used
        return bpath.decode('utf-8').split('\\')[-2]

    @staticmethod
    #depreciated
    def one_label_dataset(path, label):                                                # path taken in must be raw
        return tf.data.Dataset.zip((
            tf.data.Dataset.list_files(path),
            tf.data.Dataset.from_tensor_slices(tf.constant(value=label_to_ind[label], dtype=tf.dtypes.int32 ,shape=len(tf.data.Dataset.list_files(path))))
        ))

    @staticmethod
    def slices_for_onelabel(path, label):
        paths = os.listdir(path)
        paths = list(map(lambda x : 'DATA_NLP_TIL\\'+label+'\\'+x , paths))

        labels = [label_to_ind[label]]*len(paths)

        return paths , labels
    
    @staticmethod
    def preprocess_mel_eachlabel(file_path, label):                          
        
        data, sr = aud_util.loadaud(file_path, sr=16000, mono=True)
        data, sr = aud_util.pad_trunc(data, sr, max_ms)                                
        mel = aud_img.melspec(data, sr)
        mel = tf.expand_dims(mel, axis=2)
        
        return mel, label

    @staticmethod
    def path_to_mel(path):                                                              # temporary work around
        
        data, sr = aud_util.loadaud(path, sr=16000, mono=True)
        data, sr = aud_util.pad_trunc(data, sr, max_ms)                                
        mel = aud_img.melspec(data, sr)
        mel = tf.expand_dims(mel, axis=2)

        return mel

# %%
'''
BUILDING DATASET PIPELINE

'''


# my god...
angry, _0= ds_create.slices_for_onelabel(r'DATA_NLP_TIL\angry', 'angry')
fear, _1 = ds_create.slices_for_onelabel(r'DATA_NLP_TIL\fear', 'fear')
happy, _2 = ds_create.slices_for_onelabel(r'DATA_NLP_TIL\happy', 'happy')
neutral, _3 = ds_create.slices_for_onelabel(r'DATA_NLP_TIL\neutral', 'neutral')
sad, _4 = ds_create.slices_for_onelabel(r'DATA_NLP_TIL\sad', 'sad')

slices = angry + fear + happy + neutral + sad
labels = _0 + _1 + _2 + _3 + _4

ds = tf.data.Dataset.zip((
    tf.data.Dataset.list_files(slices, shuffle=False),
    tf.data.Dataset.from_tensor_slices(labels)
))

ds = ds.shuffle(len(ds))

# %%
'''
Temporary work around for below error

'''
# requires shuffling in tf.keras.Model.fit

X = list(map(ds_create.path_to_mel, slices))

Y = np.array(to_categorical(labels))
X = np.array(X)




'''
TASKS: MAYBE TRY LOADING THINGS INTO A DATAFRAME FOR THIS CRUDE METHOD....?

'''
# Out:
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00029892 -0.00040072 -0.00029337 ...  0.00274426  0.00912178
#  -0.00076151] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-9.41753387e-06  3.37362289e-05  1.06573105e-04 ...  1.57973170e-02
#   1.46116614e-02  1.36162043e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.0003584  -0.00037551 -0.00067168 ...  0.00812298  0.00647235
#   0.00544107] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.3351440e-05  3.2246113e-05  1.9669533e-05 ... -1.2168407e-02
#  -2.7675033e-03  1.1518776e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00368685 0.00344563 0.00187773 ... 0.02642173 0.02997971 0.06329805] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 2.3961067e-04  1.3726950e-04  4.1246414e-05 ... -1.1013985e-02
#   4.1525841e-02  9.7082376e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 1.7642975e-05  5.7339668e-05  8.1419945e-05 ... -8.0176711e-02
#   1.1566758e-02  4.3187678e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-2.5093555e-05 -6.4432621e-05  2.0205975e-05 ...  9.6261501e-05
#   6.1869621e-05  4.1723251e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.5473366e-04 -8.1241131e-05  5.0663948e-06 ... -1.9215345e-03
#   9.6166134e-04  2.4057627e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.39474869e-05 -2.70009041e-05  5.48362732e-06 ...  1.11073554e-01
#   1.04558885e-01  8.73776078e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.8775463e-05 -2.9683113e-05 -2.2053719e-06 ...  5.4081678e-03
#  -2.6082993e-04 -7.8297257e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00762033 0.01275182 0.01107329 ... 0.07187814 0.07725018 0.07455707] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 9.2387199e-06 -2.4974346e-05 -1.1801720e-05 ...  6.9886446e-04
#   5.8734417e-04  5.7196617e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-8.3446503e-07  1.3530254e-05  1.0997057e-04 ... -9.0478599e-02
#  -8.5311592e-02 -8.0651462e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00077528 -0.00104439 -0.00079584 ...  0.00765359 -0.00339228
#  -0.01034123] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.01047945  0.01757461  0.01561689 ... -0.0026024  -0.0013181
#  -0.00133991] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-2.0384789e-05 -3.5464764e-05 -1.5258789e-05 ...  5.8825749e-01
#   1.8718565e-01  5.6395531e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00123078 -0.0023579  -0.00270998 ...  0.00370002  0.00386786
#   0.00585014] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-2.2947788e-05 -8.5294247e-05 -1.0329485e-04 ... -1.1283159e-03
#  -8.9657307e-04 -1.0409355e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 5.8412552e-06 -6.2584877e-06  6.9737434e-06 ...  6.2240899e-02
#   1.1827046e-01  1.5413427e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00042695 0.00058502 0.00067741 ... 0.39775628 0.373169   0.3307224 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-3.7372112e-05 -2.1398067e-05 -1.4650822e-04 ... -4.1593492e-02
#   4.3587446e-02  1.0785878e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.4108419e-04 -3.5822392e-05  1.5860796e-04 ... -4.1553378e-03
#   5.3076148e-03  6.8550110e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 1.5735626e-05  7.4625015e-05  5.8054924e-05 ... -6.4075291e-02
#  -1.0067004e-01 -1.5269321e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.01452661  0.02487665  0.02242535 ... -0.53201276 -0.46709698
#  -0.40310568] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[1.1384487e-05 5.3346157e-05 5.6207180e-05 ... 2.8765202e-04 3.1054020e-04
#  3.6877394e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[2.0921230e-05 1.4305115e-06 2.8789043e-05 ... 1.5186131e-01 1.8775207e-01
#  1.9862270e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 2.8610229e-06  6.2704086e-05  7.4446201e-05 ...  1.7538607e-02
#   6.9911480e-03 -8.9325309e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-6.0200691e-05 -2.0337105e-04  1.6790628e-04 ... -1.0243982e-01
#  -1.1985338e-01 -1.5288812e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 4.5180321e-05  5.4538250e-05  3.7431717e-05 ... -7.0750713e-05
#  -2.6196241e-04 -2.1421909e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.5715103e-04  2.1123886e-04 -7.3194504e-05 ...  1.3154525e-01
#   1.3967222e-01  1.3499987e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 7.8678131e-06 -2.2709370e-05  7.8678131e-06 ... -7.6398611e-02
#  -7.7549160e-02 -7.6874375e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.7881393e-07 -5.9604645e-08 -4.1723251e-07 ...  3.9523840e-02
#   3.5082030e-01  4.5368725e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-9.5367432e-06 -4.5180321e-05 -4.3690205e-05 ...  3.4600496e-04
#   3.6454201e-04  4.8142672e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00653738  0.01077104  0.00935614 ... -0.05726415 -0.08600354
#  -0.10894769] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00100797 0.00151306 0.00227946 ... 0.1833331  0.27470303 0.2739312 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-5.1081181e-05 -3.2621622e-04 -2.3007393e-04 ... -7.8920603e-02
#  -5.3336978e-02  4.3397009e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.1622906e-05 -4.0233135e-05  1.5914440e-05 ... -8.1956387e-05
#  -3.2901764e-05 -1.0228157e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-3.4987926e-05 -2.1141768e-04 -1.4024973e-04 ...  5.2350760e-04
#   6.0409307e-04  7.6448917e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 1.7285347e-05  2.1445751e-04  8.9585781e-05 ...  2.8553903e-02
#  -9.0311885e-02  4.2310238e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-9.6559525e-06 -4.5001507e-05  4.1902065e-05 ... -3.1171441e-01
#  -3.1638074e-01 -3.1625956e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-4.76837158e-07  7.53998756e-05  1.02698803e-04 ...  1.26362741e-01
#   1.25351667e-01  1.23859525e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00013334 -0.00071818 -0.00107807 ...  0.00079685  0.00091904
#  -0.00397891] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00031245 -0.00106996 -0.00092518 ... -0.09800464 -0.06401539
#  -0.03075069] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.0669231e-05 -1.5127659e-04 -1.4525652e-04 ...  1.1814237e-03
#   8.2701445e-04  4.5681000e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00084591 -0.00148201 -0.0003261  ... -0.22735327 -0.22878551
#  -0.2509815 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00106466 -0.00192171 -0.00246423 ...  0.00081223  0.01088148
#   0.00490212] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00018173 -0.00084436 -0.00078005 ... -0.10722649 -0.11459786
#  -0.12868977] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.4424324e-05  1.4430285e-04  1.7493963e-04 ...  6.4956486e-02
#   6.2477648e-02  5.8460414e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.0132790e-06 -1.6689301e-06 -1.4901161e-06 ...  1.4250851e-01
#   1.6510803e-01  1.7472100e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 2.7894974e-05  3.1918287e-04  3.0636787e-04 ... -1.9877607e-01
#  -1.7929465e-01 -1.5807050e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-2.5987625e-05 -2.2912025e-04 -2.9498339e-04 ... -9.2718601e-03
#  -8.1366360e-02 -1.6808933e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.01403755  0.02378505  0.02105212 ... -0.00815976 -0.00809795
#  -0.00836301] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.6954880e-06 -9.4234943e-05 -7.8678131e-05 ... -3.2975256e-02
#  -1.1642158e-02  7.1410835e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.1650066e-05  2.7924776e-04  2.9039383e-04 ... -4.1249335e-02
#  -3.8605630e-02 -3.9048254e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-7.1525574e-07  2.9802322e-07 -4.1723251e-07 ...  6.7365110e-02
#   6.2576532e-02  1.9024968e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[1.2755394e-05 5.7816505e-05 6.1392784e-05 ... 1.8136024e-02 2.0320237e-02
#  2.7199686e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.9788742e-05 -1.7738342e-04 -2.6535988e-04 ...  5.2888036e-02
#   5.0393760e-02  4.6202123e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-8.5890293e-05 -4.0936470e-04 -4.4512749e-04 ... -1.4227629e-04
#  -1.3095140e-04 -5.6147575e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-5.3644180e-07  2.7418137e-06  1.9907951e-05 ... -1.4070976e-01
#  -1.4829844e-01 -1.4957976e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.5762787e-06  8.7201595e-05  1.2516975e-06 ... -1.7530113e-01
#  -2.2460181e-01 -2.2708303e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00330305  0.00709534  0.0056982  ... -0.0060637  -0.00482702
#  -0.01848084] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00014216 -0.00246865 -0.0036751  ... -0.00018036 -0.00018305
#  -0.00024867] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00387853 0.00636226 0.00677925 ... 0.0900206  0.08248174 0.08329296] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-7.0869923e-05 -2.9528141e-04 -3.1691790e-04 ...  3.9304256e-02
#  -3.5371482e-02  4.0104389e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.4165382e-04  3.5959482e-04 -1.7821789e-05 ... -9.8273158e-03
#  -8.2635283e-03 -7.5928569e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00162774  0.00192982  0.00162774 ...  0.0284245   0.04857492
#  -0.14782387] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.01076257  0.01757038  0.01517904 ... -0.14291865 -0.1617536
#  -0.17857456] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 7.7486038e-07  1.3113022e-06  1.1324883e-06 ... -3.5097957e-02
#  -3.3422947e-02 -3.2137990e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 5.1259995e-06  5.3644180e-07 -3.6299229e-05 ... -2.0318174e-01
#  -1.7867744e-01 -1.4373851e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[7.2181225e-05 2.4414062e-04 4.4167042e-05 ... 5.8736801e-03 1.4431477e-03
#  1.7830729e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00169241  0.00104457  0.00108653 ... -0.00090772 -0.00115168
#   0.00056684] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 6.8068504e-05  1.8566847e-04  1.8489361e-04 ... -1.1878133e-01
#  -1.2568569e-01 -1.2662816e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.02021897 0.02070266 0.02115607 ... 0.00897378 0.00852036 0.00945747] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.00069666 -0.00370592 -0.00284398 ... -0.02278525 -0.03541088
#  -0.04394293] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.01337337 -0.00686181 -0.01236671 ... -0.02177346 -0.01956546
#  -0.0206846 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 8.2850456e-06  5.0425529e-05  1.3232231e-05 ... -1.6763806e-03
#   1.0327101e-03 -1.2237430e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.6060810e-05  1.2290478e-04  1.5342236e-04 ... -1.5885174e-02
#  -1.9286394e-02 -3.7553966e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00411969 0.00457335 0.00457335 ... 0.07980925 0.29266524 0.24449372] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 4.3809414e-05 -2.0486116e-04 -3.4642220e-04 ...  1.6137481e-02
#   2.2386849e-02  2.6657879e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[1.4662743e-05 4.5657158e-05 6.0439110e-05 ... 1.2893546e-01 1.5050256e-01
#  1.6438675e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.01270431  0.0213781   0.01817465 ...  0.00259775  0.0079906
#  -0.02265298] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.03283387 0.03271395 0.03508174 ... 0.05382806 0.08926785 0.07323694] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 5.1796436e-05  1.8936396e-04  2.5504827e-04 ... -1.2928081e-01
#  -1.3871217e-01 -1.4109504e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-0.03563684 -0.03792548 -0.03717268 ...  0.2234596  -0.20481443
#  -0.154284  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00014734  0.00103933  0.00140911 ... -0.08115208 -0.07306671
#  -0.05604255] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-5.6028366e-06 -1.4930964e-04 -2.1976233e-04 ... -2.8467774e-03
#  -6.7299604e-03  8.9985132e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[-1.1503696e-05  2.8252602e-05  3.7550926e-05 ...  6.9150031e-02
#   6.9414973e-02  6.9288433e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00249732  0.00207418  0.00249732 ...  0.03268939 -0.11322397
#   0.02933472] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.00535029  0.00535029  0.00553143 ... -0.04784709 -0.05539495
#  -0.05796123] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00100416 0.00076574 0.00102538 ... 0.01059783 0.01106888 0.00816786] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[0.00314409 0.00353712 0.00474632 ... 0.01469201 0.01708013 0.02306569] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 3.7024021e-03 -4.7981739e-05 -1.3182759e-03 ... -1.0645074e-01
#  -1.0772103e-01 -1.0832596e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db
# C:\Users\zhiha\AppData\Local\Temp\ipykernel_20560\3768946378.py:64: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00179982  0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec = lb.feature.melspectrogram(data, sr=sr, power=1)                         # power = 1/2 changes amplitude_to_db or power_to_db

# %%
'''
Supposedly proper mapping that keeps throwing errors

'''
#ds = ds.map(ds_create.preprocess_mel_eachlabel)
ds = ds.map(ds_create.preprocess_mel_eachlabel)
# ds = ds.cache()
# ds = ds.batch(batchs)
# ds = ds.prefetch(16)

# %%
xin = Input(X[34].shape)
net = tf.keras.applications.efficientnet.EfficientNetB0(weights='imagenet', include_top=False)
# x = Conv2D(256, (3, 3), padding='valid', activation='swish' )(net)
# x = MaxPool2D((2, 2))(x)

# x = Conv2D(128, (3, 3), padding='valid', activation='swish' )(x)
# x = MaxPool2D((2, 2))(x)

# x = Conv2D(128, (3, 3), padding='valid', activation='swish' )(x)
# x = MaxPool2D((2, 2))(x)

x = Flatten()(net)
x = Dense(128, activation='swish')(x)
x = Dropout(0.5)(x)

xout = Dense(5, activation='softmax')(x)

own = Model(xin, xout)
own.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['acc'])
own.summary()

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.1, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint(r'Model_weights', monitor='val_loss', verbose=1, save_best_only=True)
]

# %%
history = own.fit(
    x=X,
    y=Y,
    batch_size=batchs,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 88/88 [==============================] - ETA: 0s - loss: 5.4605 - acc: 0.2389
# Epoch 1: val_loss improved from inf to 4.58305, saving model to Model_weights
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Model_weights\assets
# INFO:tensorflow:Assets written to: Model_weights\assets
# 88/88 [==============================] - 11s 118ms/step - loss: 5.4605 - acc: 0.2389 - val_loss: 4.5830 - val_acc: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.4541 - acc: 0.2597
# Epoch 2: val_loss did not improve from 4.58305
# 88/88 [==============================] - 8s 90ms/step - loss: 1.4543 - acc: 0.2589 - val_loss: 4.6122 - val_acc: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.4493 - acc: 0.2471
# Epoch 3: val_loss did not improve from 4.58305
# 88/88 [==============================] - 8s 89ms/step - loss: 1.4492 - acc: 0.2479 - val_loss: 5.1800 - val_acc: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.4403 - acc: 0.2360
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 4: val_loss did not improve from 4.58305
# 88/88 [==============================] - 8s 87ms/step - loss: 1.4402 - acc: 0.2361 - val_loss: 6.0494 - val_acc: 0.0000e+00 - lr: 0.0010
# Epoch 5/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.4345 - acc: 0.2647
# Epoch 5: val_loss did not improve from 4.58305
# 88/88 [==============================] - 8s 87ms/step - loss: 1.4348 - acc: 0.2646 - val_loss: 6.9095 - val_acc: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.4328 - acc: 0.2557
# Epoch 6: val_loss did not improve from 4.58305
# 88/88 [==============================] - 8s 87ms/step - loss: 1.4328 - acc: 0.2550 - val_loss: 7.0366 - val_acc: 0.0000e+00 - lr: 1.0000e-04
